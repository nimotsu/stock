# %%
import pandas as pd

# %%
url = "https://www.malaysiastock.biz/Corporate-Infomation.aspx?securityCode=1155"
html = pd.read_html(url)

# %%
len(html)
# Out:
# 24

# %%
for i in range(12):
    print(i)
    print(html[i])
    print()

# %%
html[1]
# Out:
#                                                     0   \
# 0    MAYBANK Share Price Movement Share Price  Chan...
# 1                                          Share Price
# 2                                                7.500
# 3                                                  NaN
# 4                                          Open: 7.520
# ..                                                 ...
# 151                                 ANNUAL REPORT 2011
# 152                                                NaN
# 153                                                NaN
# 154            kenlaw and 65 others like this company.
# 155                                                NaN
#
#                                                     1                  2   \
# 0    Ad Free Version  Corporate Information  Websit...                NaN
# 1                                               Change       Share Volume
# 2                                      -0.020 (-0.27%)              23839
# ...

# %%
share_price = tables[1].iloc[1,1]
share_price
# Out:
# 'Change'

# %%
for i in range(10):
    print(tables[1].iloc[i,:])
# Out:
# 0     MAYBANK Share Price Movement Share Price  Chan...
# 1     Ad Free Version  Corporate Information  Websit...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
tables[1].iloc[10,:]
# Out:
# 0     4 Weeks Price Range
# 1           7.470 - 7.980
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# Name: 10, dtype: object
